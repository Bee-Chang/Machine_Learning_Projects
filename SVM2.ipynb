# %% [markdown]
# https://www.kaggle.com/datasets/sayansh001/microbes-dataset
#
# https://www.kaggle.com/datasets/brsdincer/star-type-classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
df = pd.read_csv('Stars.csv')
df
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

Label = le.fit_transform(df['Color'])

df.drop('Color', axis=1, inplace=True)

df['Color'] = Label

df
# Out:
#      Temperature              L          R    A_M Spectral_Class  Type  Color
# 0           3068       0.002400     0.1700  16.12              M     0      8
# 1           3042       0.000500     0.1542  16.60              M     0      8
# 2           2600       0.000300     0.1020  18.70              M     0      8
# 3           2800       0.000200     0.1600  16.65              M     0      8
# 4           1939       0.000138     0.1030  20.06              M     0      8
# ..           ...            ...        ...    ...            ...   ...    ...
# 235        38940  374830.000000  1356.0000  -9.93              O     5      0
# 236        30839  834042.000000  1194.0000 -10.63              O     5      0
# 237         8829  537493.000000  1423.0000 -10.73              A     5      9
# 238         9235  404940.000000  1112.0000 -11.23              A     5      9
# 239        37882  294903.000000  1783.0000  -7.80              O     5      0
#
# [240 rows x 7 columns]

# %%
Label1 = le.fit_transform(df['Spectral_Class'])

df.drop('Spectral_Class', axis=1, inplace=True)

df['Spectral_Class'] = Label1

df
# Out:
#      Temperature              L          R    A_M  Type  Color  Spectral_Class
# 0           3068       0.002400     0.1700  16.12     0      8               5
# 1           3042       0.000500     0.1542  16.60     0      8               5
# 2           2600       0.000300     0.1020  18.70     0      8               5
# 3           2800       0.000200     0.1600  16.65     0      8               5
# 4           1939       0.000138     0.1030  20.06     0      8               5
# ..           ...            ...        ...    ...   ...    ...             ...
# 235        38940  374830.000000  1356.0000  -9.93     5      0               6
# 236        30839  834042.000000  1194.0000 -10.63     5      0               6
# 237         8829  537493.000000  1423.0000 -10.73     5      9               0
# 238         9235  404940.000000  1112.0000 -11.23     5      9               0
# 239        37882  294903.000000  1783.0000  -7.80     5      0               6
#
# [240 rows x 7 columns]

# %%
df.columns.values
# Out:
# array(['Temperature', 'L', 'R', 'A_M', 'Type', 'Color', 'Spectral_Class'],
#       dtype=object)

# %%
#the x data is saved without 'target' column to make only features dataframe
x=df[['Temperature', 'L', 'R', 'A_M', 'Color', 'Spectral_Class']]

# %%
#the y data is saved only with 'target' column
y=df['Type']

# %%
#create a model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=2)

# %%
#kernel specifying
clf=svm.SVC(kernel='linear')

#train and fit the model
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#predict the response
y_pred=clf.predict(x_test)

# %%
#model accuracy
print("Accuracy: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  1.0

# %%
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Precision: 1.0
# Recall: 1.0

# %%
df1 = pd.read_csv('microbes.csv')
df1
# Out:
#        Unnamed: 0  Solidity  Eccentricity  EquivDiameter  Extrema  FilledArea  \
# 0               0     10.70          15.8           5.43     3.75      0.7850
# 1               1      5.60          18.3           4.14     6.16      0.3640
# 2               2      8.32          19.8           4.63     6.66      0.4150
# 3               3     10.10          17.9           7.29    11.10      1.4700
# 4               4      6.27          20.2          20.10    10.70     14.7000
# ...           ...       ...           ...            ...      ...         ...
# 30522       30522      3.01          22.6           4.90    20.00      0.4340
# 30523       30523      5.19          22.6           2.07    19.40      0.0788
# 30524       30524      9.21          22.7           2.07    21.00      0.0790
# 30525       30525      8.21          22.6           1.87    20.50      0.0641
# 30526       30526      6.57          21.0           2.13    21.20      0.0840
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

Label2 = le.fit_transform(df1['microorganisms'])

df1.drop('microorganisms', axis=1, inplace=True)

df1['microorganisms'] = Label2

df1
# Out:
#        Unnamed: 0  Solidity  Eccentricity  EquivDiameter  Extrema  FilledArea  \
# 0               0     10.70          15.8           5.43     3.75      0.7850
# 1               1      5.60          18.3           4.14     6.16      0.3640
# 2               2      8.32          19.8           4.63     6.66      0.4150
# 3               3     10.10          17.9           7.29    11.10      1.4700
# 4               4      6.27          20.2          20.10    10.70     14.7000
# ...           ...       ...           ...            ...      ...         ...
# 30522       30522      3.01          22.6           4.90    20.00      0.4340
# 30523       30523      5.19          22.6           2.07    19.40      0.0788
# 30524       30524      9.21          22.7           2.07    21.00      0.0790
# 30525       30525      8.21          22.6           1.87    20.50      0.0641
# 30526       30526      6.57          21.0           2.13    21.20      0.0840
#
# ...

# %%
df1.columns.values
# Out:
# array(['Unnamed: 0', 'Solidity', 'Eccentricity', 'EquivDiameter',
#        'Extrema', 'FilledArea', 'Extent', 'Orientation', 'EulerNumber',
#        'BoundingBox1', 'BoundingBox2', 'BoundingBox3', 'BoundingBox4',
#        'ConvexHull1', 'ConvexHull2', 'ConvexHull3', 'ConvexHull4',
#        'MajorAxisLength', 'MinorAxisLength', 'Perimeter', 'ConvexArea',
#        'Centroid1', 'Centroid2', 'Area', 'raddi', 'microorganisms'],
#       dtype=object)

# %%
#the x data is saved without 'target' column to make only features dataframe
x=df1[['Solidity', 'Eccentricity', 'EquivDiameter',
       'Extrema', 'FilledArea', 'Extent', 'Orientation', 'EulerNumber',
       'BoundingBox1', 'BoundingBox2', 'BoundingBox3', 'BoundingBox4',
       'ConvexHull1', 'ConvexHull2', 'ConvexHull3', 'ConvexHull4',
       'MajorAxisLength', 'MinorAxisLength', 'Perimeter', 'ConvexArea',
       'Centroid1', 'Centroid2', 'Area', 'raddi']]

# %%
y=df1['microorganisms']

# %%
#create a model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=2)

# %%
#kernel specifying
clf=svm.SVC(kernel='linear')

#train and fit the model
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#predict the response
y_pred=clf.predict(x_test)

# %%
#model accuracy
print("Accuracy: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.530789387487717

# %%
precision = metrics.precision_score(y_test, y_pred, average='macro')
recall = metrics.recall_score(y_test, y_pred, average='micro')

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Precision: 0.5859495829184767
# Recall: 0.530789387487717
