# %%
from sklearn import datasets
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Loan_Default.csv')
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='plasma')

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


label = le.fit_transform(df['loan_limit'])
df.drop('loan_limit',axis=1, inplace=True)
label1 = le.fit_transform(df['Gender'])
df.drop('Gender',axis=1, inplace=True)
label2 = le.fit_transform(df['approv_in_adv'])
df.drop('approv_in_adv',axis=1, inplace=True)
label3 = le.fit_transform(df['loan_type'])
df.drop('loan_type',axis=1, inplace=True)
label4 = le.fit_transform(df['loan_purpose'])
df.drop('loan_purpose',axis=1, inplace=True)
label5 = le.fit_transform(df['Credit_Worthiness'])
df.drop('Credit_Worthiness',axis=1, inplace=True)
label6 = le.fit_transform(df['open_credit'])
df.drop('open_credit',axis=1, inplace=True)
label7 = le.fit_transform(df['business_or_commercial'])
df.drop('business_or_commercial',axis=1, inplace=True)
label8 = le.fit_transform(df['Neg_ammortization'])
df.drop('Neg_ammortization',axis=1, inplace=True)
label9 = le.fit_transform(df['interest_only'])
df.drop('interest_only',axis=1, inplace=True)
label10 = le.fit_transform(df['lump_sum_payment'])
df.drop('lump_sum_payment',axis=1, inplace=True)
label11 = le.fit_transform(df['construction_type'])
df.drop('construction_type',axis=1, inplace=True)
label12 = le.fit_transform(df['occupancy_type'])
df.drop('occupancy_type',axis=1, inplace=True)
label13 = le.fit_transform(df['Secured_by'])
df.drop('Secured_by',axis=1, inplace=True)
label14 = le.fit_transform(df['total_units'])
df.drop('total_units',axis=1, inplace=True)
label15 = le.fit_transform(df['credit_type'])
df.drop('credit_type',axis=1, inplace=True)
label16 = le.fit_transform(df['Credit_Score'])
df.drop('Credit_Score',axis=1, inplace=True)
label17 = le.fit_transform(df['co-applicant_credit_type'])
df.drop('co-applicant_credit_type',axis=1, inplace=True)
label18 = le.fit_transform(df['submission_of_application'])
df.drop('submission_of_application',axis=1, inplace=True)
label19 = le.fit_transform(df['Region'])
df.drop('Region',axis=1, inplace=True)
label20 = le.fit_transform(df['Security_Type'])
df.drop('Security_Type',axis=1, inplace=True)

# %%
df.head()
# Out:
#       ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0  24890  2019       116500               NaN                   NaN
# 1  24891  2019       206500               NaN                   NaN
# 2  24892  2019       406500              4.56                0.2000
# 3  24893  2019       456500              4.25                0.6810
# 4  24894  2019       696500              4.00                0.3042
#
#    Upfront_charges   term  property_value   income    age        LTV  Status  \
# 0              NaN  360.0        118000.0   1740.0  25-34  98.728814       1
# 1              NaN  360.0             NaN   4980.0  55-64        NaN       1
# 2            595.0  360.0        508000.0   9480.0  35-44  80.019685       0
# 3              NaN  360.0        658000.0  11880.0  45-54  69.376900       0
# 4              0.0  360.0        758000.0  10440.0  25-34  91.886544       0
#
#    dtir1
# 0   45.0
# 1    NaN
# 2   46.0
# 3   42.0
# 4   39.0

# %%
df.fillna(value=0, inplace=True)
df.head()
# Out:
#       ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0  24890  2019       116500              0.00                0.0000
# 1  24891  2019       206500              0.00                0.0000
# 2  24892  2019       406500              4.56                0.2000
# 3  24893  2019       456500              4.25                0.6810
# 4  24894  2019       696500              4.00                0.3042
#
#    Upfront_charges   term  property_value   income    age        LTV  Status  \
# 0              0.0  360.0        118000.0   1740.0  25-34  98.728814       1
# 1              0.0  360.0             0.0   4980.0  55-64   0.000000       1
# 2            595.0  360.0        508000.0   9480.0  35-44  80.019685       0
# 3              0.0  360.0        658000.0  11880.0  45-54  69.376900       0
# 4              0.0  360.0        758000.0  10440.0  25-34  91.886544       0
#
#    dtir1
# 0   45.0
# 1    0.0
# 2   46.0
# 3   42.0
# 4   39.0

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='plasma')

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %% [markdown]
# Looking at the before and after changes to the heat map we can see that the numbers do change, meaning their correlation strength to each other. Even some numbers apeared where there once none, but the year remains blank as it was just 2019 all the way down.
#
# With that said I am still unsure of which is more reliable, my renewed data heatmap or the old one. For the sake of the lab we are using mine. In my opinion the column we should be looking at is the correlations to 'loan_amount' for judging which scenarios the bank has the best chances of a successful loan.

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_amount', 'rate_of_interest', 'Interest_rate_spread',
#        'Upfront_charges', 'term', 'property_value', 'income', 'age', 'LTV',
#        'Status', 'dtir1'],
#       dtype='object')

# %% [markdown]
# wait, what happended to all my columns? what...

# %%
newcols = ['ID', 'loan_amount', 'Interest_rate_spread', 'term', 'property_value']
df= df.reindex(columns = newcols)
df.head()
# Out:
#       ID  loan_amount  Interest_rate_spread   term  property_value
# 0  24890       116500                0.0000  360.0        118000.0
# 1  24891       206500                0.0000  360.0             0.0
# 2  24892       406500                0.2000  360.0        508000.0
# 3  24893       456500                0.6810  360.0        658000.0
# 4  24894       696500                0.3042  360.0        758000.0

# %%
bins = [0, 300000, 600000, 800000]
labels = ["low","median","high"]
df['Loan_Label'] = pd.cut(df['loan_amount'], bins=bins, labels=labels)
df.drop('loan_amount',axis =1, inplace = True)
df.head()
# Out:
#       ID  Interest_rate_spread   term  property_value Loan_Label
# 0  24890                0.0000  360.0        118000.0        low
# 1  24891                0.0000  360.0             0.0        low
# 2  24892                0.2000  360.0        508000.0     median
# 3  24893                0.6810  360.0        658000.0     median
# 4  24894                0.3042  360.0        758000.0       high

# %%
bins = [0, 270000, 600000, 16508000]
labels = ["poor","normal","excellent"]
df['Property_Label'] = pd.cut(df['property_value'], bins=bins, labels=labels)
df.drop('property_value',axis =1, inplace = True)
df.head()
# Out:
#       ID  Interest_rate_spread   term Loan_Label Property_Label
# 0  24890                0.0000  360.0        low           poor
# 1  24891                0.0000  360.0        low            NaN
# 2  24892                0.2000  360.0     median         normal
# 3  24893                0.6810  360.0     median      excellent
# 4  24894                0.3042  360.0       high      excellent

# %%
df['Loan_Label'].value_counts()
# Out:
# low       75212
# median    61420
# high      10143
# Name: Loan_Label, dtype: int64

# %%
df['Property_Label'].value_counts()
# Out:
# normal       63534
# excellent    36522
# poor         33516
# Name: Property_Label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
result = df['Property_Label']
df.drop(['Property_Label'], axis=1, inplace=True)
print(df.shape, result.shape)
# Out:
# (148670, 4) (148670,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df, result, test_size=0.30, random_state=11)

# %%
scaler = StandardScaler()
scaler.fit(df)
scaled_features = scaler.transform(df)
df_sc = pd.DataFrame(scaled_features, columns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-371-a1e5bbcdaece> in <module>
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(df)
#       3 scaled_features = scaler.transform(df)
#       4 df_sc = pd.DataFrame(scaled_features, columns=df.columns)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     822         # Reset internal state before fitting
#     823         self._reset()
# --> 824         return self.partial_fit(X, y, sample_weight)
#     825
#     826     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     859
#     860         first_call = not hasattr(self, "n_samples_seen_")
# --> 861         X = self._validate_data(
#     862             X,
# ...

# %%
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(df_sc, result, test_size=0.30, random_state=11)

# %%
X_train_sc = X_train_sc.to_numpy()
y_train_sc = y_train_sc.to_numpy()

# %%
def apply_knn(neigh, weight='uniform'):
    knn = KNeighborsClassifier(n_neighbors=neigh, weights=weight)
    knn.fit(X_train_sc,y_train_sc)
    pred_knn = knn.predict(X_test_sc)
    return pred_knn

# %%
pred_knn_for_20 = apply_knn(20)
print('Accuracy of model at K=20 is', accuracy_score(y_test_sc, pred_knn_for_20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-375-118f59c6744f> in <module>
# ----> 1 pred_knn_for_20 = apply_knn(20)
#       2 print('Accuracy of model at K=20 is', accuracy_score(y_test_sc, pred_knn_for_20))
#
# <ipython-input-374-d93ed6b60c8d> in apply_knn(neigh, weight)
#       1 def apply_knn(neigh, weight='uniform'):
#       2     knn = KNeighborsClassifier(n_neighbors=neigh, weights=weight)
# ----> 3     knn.fit(X_train_sc,y_train_sc)
#       4     pred_knn = knn.predict(X_test_sc)
#       5     return pred_knn
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score


# split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.3, random_state=42)

# train k-NN classifier
k = 5  # number of neighbors to consider
clf = KNeighborsClassifier(n_neighbors=k)
clf.fit(X_train, y_train)

# make predictions on testing set
y_pred = clf.predict(X_test)

# evaluate accuracy of predictions
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.06679222438958768

# %% [markdown]
# I don't know where or how to fix my orginal line of work, but I found this simplified version and with my data being as messed up as it is I can't seem to get it any better.
#
# So, the best possible conclusion I can give based off of the data that I inputed is that property value, income, etc. alone cannot give us enough information to confidently selectively choose who we can and cannot give loans out to to maximize our profits. I think that I've spent long enough on this to have this as a suitable conclusion for me
